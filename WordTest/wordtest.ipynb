# %%
# !pip install python-docx
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------- ----------------------- 1.6/3.8 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 6.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install PyPDF2
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PyPDF2 import PdfReader

reader = PdfReader("C:/Users/huije/Desktop/뜯어먹는_수능_1등급_기본_영단어_1800_개정판__단어_리스트_241130_083500.pdf")
for page in reader.pages:
    print(page.extract_text())
# Out:
# 뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
# 뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
#  단어 리스트
# 뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
# DAY 01
# 01 environment 환경
# 02 government 정부, 정치
# 03 company 회사, 함께 있음[동반/교제], 친구[손님]들
# 04 race 경주[경쟁], 인종, 경주[경쟁]하다
# 05 plant 식물, 공장[설비], 심다
# 06 state 상태, 국가, (미국의 ) 주, 말하다 [진술하다 ]
# 07 concern 우려[걱정], 관심(사), 관련되다 , 걱정시키다
# 08 reason 이유, 이성, 추론하다
# 09 face 얼굴, 직면하다
# 10 fire 불, 화재, 발사하다 , 해고하다
# 11 matter 문제, 물질, 중요하다
# 12 cause 원인, 이유, 일으키다 [원인이 되다]
# 13 raise (들어) 올리다 , 모금하다 , 기르다 , 제기하다 , 임금 인상
# 14 bear 참다[견디다 ], 지니다 , 떠맡다 , 곰
# 15 support 지지하다 , 부양[원조]하다, 지지, 원조
# 16 allow 허락[허용]하다
# 17 consider 고려[숙고/배려]하다, 여기다
# 18 provide 제공[공급]하다
# 19 realize 깨닫다 , 실현하다
# 20 reduce 줄이다 , 축소하다
# 21 suggest 제안하다 [권하다 ], 암시하다
# 22 subject 주제, 과목, 실험 대상, 영향 받기 쉬운, 복속시키다
# 23 present 있는[참석한 ], 현재의 , 선물, 현재, 증정하다 , 제시하다
# 24 mean 의미하다 , 의도하다 , 못된[심술궂은 ]
# 25 patient 환자, 참을성 있는
# 26 individual 개인[개개]의, 개인
# 27 ancient 고대의 , 오래된 , 고대인들
# 28 various 다양한
# 29 positive 긍정적인 [적극적인 ]
# ...

# %%
booktext = ""
for page in reader.pages:
    booktext += page.extract_text()

print(booktext)
# Out:
# 뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
# 뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
#  단어 리스트   뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
# DAY 01
# 01 environment 환경
# 02 government 정부, 정치
# 03 company 회사, 함께 있음[동반/교제], 친구[손님]들
# 04 race 경주[경쟁], 인종, 경주[경쟁]하다
# 05 plant 식물, 공장[설비], 심다
# 06 state 상태, 국가, (미국의 ) 주, 말하다 [진술하다 ]
# 07 concern 우려[걱정], 관심(사), 관련되다 , 걱정시키다
# 08 reason 이유, 이성, 추론하다
# 09 face 얼굴, 직면하다
# 10 fire 불, 화재, 발사하다 , 해고하다
# 11 matter 문제, 물질, 중요하다
# 12 cause 원인, 이유, 일으키다 [원인이 되다]
# 13 raise (들어) 올리다 , 모금하다 , 기르다 , 제기하다 , 임금 인상
# 14 bear 참다[견디다 ], 지니다 , 떠맡다 , 곰
# 15 support 지지하다 , 부양[원조]하다, 지지, 원조
# 16 allow 허락[허용]하다
# 17 consider 고려[숙고/배려]하다, 여기다
# 18 provide 제공[공급]하다
# 19 realize 깨닫다 , 실현하다
# 20 reduce 줄이다 , 축소하다
# 21 suggest 제안하다 [권하다 ], 암시하다
# 22 subject 주제, 과목, 실험 대상, 영향 받기 쉬운, 복속시키다
# 23 present 있는[참석한 ], 현재의 , 선물, 현재, 증정하다 , 제시하다
# 24 mean 의미하다 , 의도하다 , 못된[심술궂은 ]
# 25 patient 환자, 참을성 있는
# 26 individual 개인[개개]의, 개인
# 27 ancient 고대의 , 오래된 , 고대인들
# 28 various 다양한
# 29 positive 긍정적인 [적극적인 ]
# ...

# %%
def extract_lines_after_keyword(text, keyword, num_lines=30):
    """
    멀티라인 텍스트에서 특정 키워드 이후의 N 라인을 추출합니다.

    Args:
        text (str): 멀티라인 텍스트.
        keyword (str): 검색할 키워드.
        num_lines (int): 키워드 이후에 가져올 라인의 수 (기본값: 30).

    Returns:
        list: 키워드 이후의 N 라인을 포함한 리스트.
    """
    # 텍스트를 줄 단위로 분리
    lines = text.splitlines()

    # 키워드가 있는 줄 찾기
    for i, line in enumerate(lines):
        if keyword in line:
            # 키워드 이후의 라인 추출
            return lines[i + 1:i + 1 + num_lines]

    # 키워드가 없으면 빈 리스트 반환
    return []

# %%
keyword = "DAY 58"
result1 = extract_lines_after_keyword(booktext, keyword, num_lines=30)
keyword = "DAY 59"
result2 = extract_lines_after_keyword(booktext, keyword, num_lines=30)

result = result1 + result2

print("결과:")
print("\n".join(result))
# Out:
# 결과:
# 01 niece 조카딸
# 02 merchant 상인[무역상 ]
# 03 beast 짐승[야수]
# 04 tag 꼬리표 [이름표 /정가표 ]
# 05 margin 여백, 차이, 수익, 가장자리
# 06 machinery (집합적 ) 기계(류), 기계 부품들
# 07 publicity 홍보[광고](업), 매스컴의 관심
# 08 contradiction 모순, 반박
# 09 reference 언급, 참고 (문헌), 추천(인)
# 10 bunch 다발[송이/묶음], 많은 수[양]
# 11 peer 또래, 유심히 보다[응시하다 ]
# 12 caution 조심[주의/경고], 경고하다 [주의를 주다]
# 13 revenge 복수[보복], 복수하다
# 14 yawn 하품하다 , 하품
# 15 trim 다듬다 , 줄이다 , 다듬기 , 장식
# 16 roast 굽다, 구운 고기
# 17 devise 고안[창안]하다
# 18 amuse 즐겁게 [재미있게 ] 하다
# 19 withdraw (예금을 ) 인출하다 , 철수[철회]하다
# 20 sprain 삐다
# 21 hasten 서두르다 , 재촉하다 [앞당기다 ]
# 22 bind 묶다, 감다, 결속시키다
# 23 certify 증명[보증]하다
# 24 coordinate 조직화 [조정]하다
# 25 ripe 익은, 준비가 된
# 26 favorable 호의적인 [유리한 ]
# 27 resentful 분개한
# 28 probable 개연성 있는[~일 것 같은]
# 29 athletic 운동(선수)의
# 30 checked 체크[바둑판 ]무늬의뜯어먹는 수능 1등급 기본 영단어 1800(개정판 )
# 01 patriot 애국자
# 02 auditorium 청중[관객]석, 강당
# 03 meadow 풀밭[초원]
# 04 hay 건초
# 05 kettle 주전자 , 솥
# 06 vapor (수)증기
# 07 enrollment 등록, 등록자 수
# 08 compassion 동정심 [연민]
# 09 impulse 충동
# ...

# %%
len(result)
# Out:
# 60

# %%
list = []
for txt in result:
    list.append(extract_second_word(txt))

# %%
list
# Out:
# ['niece',
#  'merchant',
#  'beast',
#  'tag',
#  'margin',
#  'machinery',
#  'publicity',
#  'contradiction',
#  'reference',
#  'bunch',
#  'peer',
#  'caution',
#  'revenge',
#  'yawn',
#  'trim',
#  'roast',
#  'devise',
#  'amuse',
#  'withdraw',
#  'sprain',
#  'hasten',
#  'bind',
#  'certify',
#  'coordinate',
#  'ripe',
#  'favorable',
#  'resentful',
#  'probable',
#  'athletic',
#  'checked',
#  'patriot',
#  'auditorium',
#  'meadow',
#  'hay',
#  'kettle',
#  'vapor',
#  'enrollment',
#  'compassion',
#  'impulse',
#  'mode',
#  'bud',
#  'esteem',
#  'switch',
#  'retreat',
#  'tease',
#  'maximize',
#  'swell',
#  'dip',
#  'astonish',
#  'vomit',
#  'contend',
#  'justify',
#  'radical',
#  'bilingual',
#  'abundant',
#  'evident',
#  'gorgeous',
#  'solemn',
#  'homesick',
#  'ironic']

# %%
len(list)
# Out:
# 60

# %%
def extract_second_word(text):
    """
    문자열에서 두 번째 단어를 추출합니다.

    Args:
        text (str): 입력 문자열.

    Returns:
        str: 두 번째 단어. 두 번째 단어가 없으면 빈 문자열 반환.
    """
    # 문자열을 공백 기준으로 분리
    words = text.split()
    
    # 두 번째 단어가 있으면 반환, 없으면 빈 문자열 반환
    return words[1] if len(words) > 1 else ""

# 사용 예제
text1 = "Hello world! Welcome to Python."
text2 = "OneWord"
text3 = "  Extra spaces at start and end  "

print(extract_second_word(text1))  # 결과: "world!"
print(extract_second_word(text2))  # 결과: ""
print(extract_second_word(text3))  # 결과: "spaces"
# Out:
# world!
#
# spaces

# %%
import random

# %%
random.shuffle(list)

# %%
list
# Out:
# ['hasten',
#  'probable',
#  'tag',
#  'yawn',
#  'contend',
#  'ironic',
#  'vomit',
#  'ripe',
#  'impulse',
#  'coordinate',
#  'bud',
#  'revenge',
#  'esteem',
#  'reference',
#  'radical',
#  'trim',
#  'bind',
#  'vapor',
#  'resentful',
#  'enrollment',
#  'bunch',
#  'auditorium',
#  'caution',
#  'beast',
#  'hay',
#  'contradiction',
#  'margin',
#  'withdraw',
#  'peer',
#  'evident',
#  'homesick',
#  'machinery',
#  'astonish',
#  'maximize',
#  'sprain',
#  'justify',
#  'publicity',
#  'favorable',
#  'compassion',
#  'checked',
#  'abundant',
#  'roast',
#  'certify',
#  'niece',
#  'meadow',
#  'swell',
#  'bilingual',
#  'merchant',
#  'amuse',
#  'athletic',
#  'solemn',
#  'devise',
#  'gorgeous',
#  'retreat',
#  'patriot',
#  'kettle',
#  'mode',
#  'dip',
#  'tease',
#  'switch']

# %%
from docx import Document

doc = Document('C:/Users/huije/Desktop/Word Test Format.docx')

# %%
table = doc.tables[0]

# %%
len(table.rows)
# Out:
# 31

# %%
len(table.columns)
# Out:
# 6

# %%
cRow=1
bCol = True

# %%
half = int(len(list)/2)
half
# Out:
# 30

# %%
len(list[:half])
# Out:
# 30

# %%
len(list[half:])
# Out:
# 30

# %%
list[:half]
# Out:
# ['hasten',
#  'probable',
#  'tag',
#  'yawn',
#  'contend',
#  'ironic',
#  'vomit',
#  'ripe',
#  'impulse',
#  'coordinate',
#  'bud',
#  'revenge',
#  'esteem',
#  'reference',
#  'radical',
#  'trim',
#  'bind',
#  'vapor',
#  'resentful',
#  'enrollment',
#  'bunch',
#  'auditorium',
#  'caution',
#  'beast',
#  'hay',
#  'contradiction',
#  'margin',
#  'withdraw',
#  'peer',
#  'evident']

# %%
list[half:]
# Out:
# ['homesick',
#  'machinery',
#  'astonish',
#  'maximize',
#  'sprain',
#  'justify',
#  'publicity',
#  'favorable',
#  'compassion',
#  'checked',
#  'abundant',
#  'roast',
#  'certify',
#  'niece',
#  'meadow',
#  'swell',
#  'bilingual',
#  'merchant',
#  'amuse',
#  'athletic',
#  'solemn',
#  'devise',
#  'gorgeous',
#  'retreat',
#  'patriot',
#  'kettle',
#  'mode',
#  'dip',
#  'tease',
#  'switch']

# %%
cRow = 1
for word in list[:half]:
    table.cell(cRow, 1).text = word
    cRow += 1

cRow = 1
for word in list[half:]:
    table.cell(cRow, 4).text = word    
    cRow += 1

# %%
doc.save('C:/Users/huije/Desktop/Word Test Format2.docx')

# %%
# !pip install docx2pdf
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from docx2pdf import convert

inputFile = 'C:/Users/huije/Desktop/Word Test Format2.docx'
outputFile = 'C:/Users/huije/Desktop/Word Test Format2.pdf'

convert(inputFile, outputFile)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import smtplib

# %%
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

def send_email_with_attachment(sender_email, sender_password, recipient_email, subject, body, attachment_path):
    smtp_server = "smtp.gmail.com"
    smtp_port = 587

    # 이메일 메시지 구성
    msg = MIMEMultipart()
    msg["Subject"] = subject
    msg["From"] = sender_email
    msg["To"] = recipient_email

    # 이메일 본문 추가
    msg.attach(MIMEText(body, "plain"))

    # 첨부 파일 추가
    with open(attachment_path, "rb") as attachment:
        part = MIMEBase("application", "octet-stream")
        part.set_payload(attachment.read())

    encoders.encode_base64(part)
    part.add_header(
        "Content-Disposition",
        f"attachment; filename={attachment_path.split('/')[-1]}",
    )
    msg.attach(part)

    # SMTP 서버 연결 및 이메일 전송
    try:
        server = smtplib.SMTP(smtp_server, smtp_port)
        server.starttls()
        #server.login(sender_email, sender_password)bbel wxpe xfam tfkl
        server.login(sender_email, sender_password)
        server.sendmail(sender_email, recipient_email, msg.as_string())
        print("이메일이 성공적으로 전송되었습니다.")
    except Exception as e:
        print(f"이메일 전송 실패: {e}")
    finally:
        server.quit()

# %%
# 사용 예제
send_email_with_attachment(
    sender_email="girltalk0001@gmail.com",
    sender_password="",  # 앱 비밀번호 사용 권장
    recipient_email="girltalk0001@gmail.com",
    subject="첨부 파일 테스트",
    body="이메일 본문에 첨부 파일을 포함합니다.",
    attachment_path="C:/Users/huije/Desktop/Word Test Format2.pdf"
)
# Out:
# 이메일이 성공적으로 전송되었습니다.
